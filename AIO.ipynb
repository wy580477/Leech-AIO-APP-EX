# %%
#@title  { vertical-output: true, display-mode: "form" }
#@markdown <center><h3> <br><b>Colab-AIO-APP-EX </h3></center><br>
#@markdown <h3>⬅️ Click to Install | 点击运行单元格安装 </h3>

from google.colab import drive
drive.mount("/content/drive", force_remount=True)

#@markdown <h3> Set language of portal page, qBit & filebrowser. </h3>
#@markdown <h3> 设置导航页、qBit 和 Filebrowser 界面语言，chs 为中文。 </h3>
GLOBAL_LANGUAGE = "en" # @param ["en", "chs"]
#@markdown <h3> Whether to Install pyLoad download manager. "Enable" will result in longer install time.</h3>
#@markdown <h3> 是否安装 pyLoad 下载管理器，启用会增加安装时间。 </h3>
PYLOAD_INSTALL = "Disable"  # @param ["Enable", "Disable"]

# !echo GLOBAL_LANGUAGE=$GLOBAL_LANGUAGE >/etc/env
# !echo PYLOAD_INSTALL=$PYLOAD_INSTALL >>/etc/env
# !mkdir /workdir
# !unzip -qd /workdir /content/drive/*/AIO_FILES/*.zip
# !cp -r /workdir/*/content/* /workdir/
# !sed -i $'s/\\r$//' /workdir/install.sh
# !bash /workdir/install.sh

# %%
#@title  { vertical-output: true, display-mode: "form" }
#@markdown <h3>⬅️ Click to Start Cloudflare Argo Tunnel </h3>
#@markdown <h3>⬅️ 点击启动 Cloudflare Argo 隧道 </h3>

# !/workdir/cloudflared.sh
